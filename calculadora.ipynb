# %% [markdown]
# <a href="https://colab.research.google.com/github/giovannasoliveira2021/calculadora/blob/main/calculadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importando as bibliotecas
# lembrand se nao estamos no colab, devemos
# fazer o comando pip install NOME_DA_BIBLIOTECA
import numpy as np
# numpy é uma biblioteca de funções matemáticas
# np é o apelido que usamos para ela

# %%
# sem usar o numpy
# matematica básica
numero1 = float(input("informe o primeiro número"))
numero2 = float(input("informe o segundo número"))

# soma
soma = numero1 + numero2
print (soma)
# subração
subtracao = numero1 - numero2
print(subtracao)
# divisao
divi = numero1/numero2
print(divi)
# multiplicação
multi = numero1 * numero2
print(multi)
# Out:
# informe o primeiro número2
# informe o segundo número7
# 9.0
# -5.0
# 0.2857142857142857
# 14.0

# %%
# usando o numpy
# matematica básica
numero1 = float(input("informe o primeiro número"))
numero2 = float(input("informe o segundo número"))

# soma pode ser sum ou add
print(f"soma: {np.add(numero1,numero2)}")
# ou o método sum - só para numeros inteiros
# print(f"soma: {np.sum(numero1, numero2)}")

# subtrair
print(f"subtração: {np.subtract(numero1, numero2)}")
# multiplicar
print(f"multiplicação: {np.multiply(numero1, numero2)}")
# dividir
print(f"divisão: {np.divide(numero1, numero2)}")
# Out:
# informe o primeiro número3
# informe o segundo número4
# soma: 7.0
# subtração: -1.0
# multiplicação: 12.0
# divisão: 0.75

# %%
while True:
  # while True não necessita de uma condição para
  # inicio ou fim
  # ------
  # para finalizar o while True usamos o caso BREAK
  print("---- CALCULADORA ----")
  print("1 - somar")
  print("2 - subtrair")
  print("3 - multiplicar")
  print("4 - dividir")
  print("0 - sair")

  op = input("escolha a opção")

  if op == "0":
    break
  elif op == "1":
    print(soma)
  elif op == "2":
    print(subtracao)
  elif op == "3":
    print(multi)
  elif op == "4":
    print(divi)
  else:
    print("Op nao encontrada")
# Out:
# ---- CALCULADORA ----
# 1 - somar
# 2 - subtrair
# 3 - multiplicar
# 4 - dividir
# 0 - sair
# escola a opção0

# %%
# usando sistema de calculadora - CAIXA DE SUPERMERCADO
# quais elementos tem  o pagamento?

# temos produtos
# temos quantidades
# temos um toltal
lista_nome = []
lista_quantidade = []
lista_valor = []
while True:

  op_tem = input("Tem algum produto para passar? S/N")
  if op_tem.lower() == "n" :
    print("sistema finalizado")
    break
  elif op_tem.lower() == "s" :
    while True:
      # precisamos de variaveis
      # precisamos de listas

      nome = input("Qual o produto?")
      valor = float(input("Qual o valor?"))
      quantidade = float(input("qual a quantidade"))
      lista_nome.append(nome)
      lista_valor.append(valor)
      lista_quantidade.append(quantidade)

      op_novo_produto = input("tem outro produto? S/N")

      if op_novo_produto.lower() == "n":
        print("indo para a nota fiscal")
        # vai ter coisas aqui
        print("----CUPOM FISCAL----")
        print("Produto | Valor | Quantidade | Total")
        # i - produto --- j - valor --- k - quantidade
        # o total é uma multiplicação - valor e a quantidade
        # transformar a lista em numpy
        np_valor = np.array(lista_valor)
        np_quantidade = np.array(lista_quantidade)
        #np.array() - transforma um conjunto de numeros para numpy
        total = np.multiply(lista_valor, lista_quantidade)
        for i,j,k,l in zip(lista_nome, lista_valor, lista_quantidade, total):
          print(f"{i} -- {j} -- {k} -- {l}")
        break
      else:
        print("informe o nome do produto")
# Out:
# indo para a nota fiscal
# ----CUPOM FISCAL----
# Produto | Valor | Quantidade | Total
# hhi -- 5.0 -- 3.0 -- 15.0
